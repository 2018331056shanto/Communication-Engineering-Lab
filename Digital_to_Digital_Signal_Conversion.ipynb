# %% [markdown]
# # **Digital-Digital conversion techniques (Line Coding)**
#
# **Reg:2018331056**
# ### 3. Write a program to simulate the digital-digital conversion techniques NRZ, NRZ-L, Manchester and Differential Manchester.
#
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## NRZ (Non-Return-to-Zero)
# In NRZ the positive voltage defines bit 1 and the zero voltage defines bit 0.
# It is called NRZ because the signal does not return to zero at the middle of the bit.

# %%
def plotNrz(data):
  x=np.arange(0,len(data),0.01)
  y=np.empty(0)
  for val in data:
    if val=='0':
       y=np.concatenate((y, np.zeros(100)))
       
    else:
       y=np.concatenate((y, np.ones(100)))
  
  plt.figure(figsize=(20,10))
  plt.subplot(222)
  plt.plot(x,y,lineWidth=3)
  plt.xlabel('Time')
  plt.ylabel('Amplitude')
  plt.title('NRZ')
  plt.yticks([0,0.5,1])
  plt.grid('on')
  plt.show()


data="100100101"
plotNrz(data)

# %% [markdown]
# # NRZ-L
# In NRZ-L the level of the voltage determines the value of the bit
# We assume bit 1 is represented by a positive voltage and bit 0 is represented by a negative voltage.

# %%
def plotNrzL(data):
  x=np.arange(0,len(data),0.01)
  y=np.empty(0)
  for val in data:
    if val=='0':
       y=np.concatenate((y, np.ones(100)*(-1)))
       
    else:
       y=np.concatenate((y, np.ones(100)))
  
  plt.figure(figsize=(20,10))
  plt.subplot(221)
  plt.plot(x,y,lineWidth=2)
  plt.yticks([-1,0,1])
  plt.xlabel('Time')
  plt.ylabel('Amplitude')
  plt.title('NRZ-L')
  plt.grid('on')

  

data="100100101"
plotNrzL(data)

# %% [markdown]
# # Manchester
# In Manchester encoding, the duration of the bit is divided into two halves.
# The voltage remains at one level during the first half and moves to the other level in the second half.
# If the bit is 0 then its moves -1 to 1 and if the bit is 1 then it moves otherwise.

# %%
def Manchester(data):

  x=np.arange(0,len(data),0.01)
  y=np.empty(0)

  for bit in data:
    if bit=='1':
      y=np.concatenate((y,np.ones(50)*-1))
      y=np.concatenate((y,np.ones(50)))
    else:
      y=np.concatenate((y,np.ones(50)))
      y=np.concatenate((y,np.ones(50)*-1))

  plt.figure(figsize=(15,7))
  plt.xlabel("Sample")
  plt.ylabel("Amplitude")
  plt.yticks([-1,0,1])
  plt.title("Manchester")
  plt.plot(x,y)
  



data=input("Enter Data : ")
Manchester(data)
# Out:
# Enter Data : 010011

# %% [markdown]
# # Differential Manchester
#
#
# Differential Manchester, combines the ideas of RZ and NRZ-I.
# There is always a transition at the middle of the bit, but the bit values are determined at the beginning of the bit.
# If the next bit is 0, there is a transition; if the next bit is 1 no transition.

# %%
import matplotlib.pyplot as plt
import numpy as np
def differentialManchester(data):
  x=np.arange(-.5,len(data),.01)
  y=np.empty(0)
  y=np.concatenate((y,np.ones(50)))
  
  prevstate=1
  for bit in data:
    if bit=='0':
      if prevstate==-1:
        y=np.concatenate((y,np.ones(50)))
        y=np.concatenate((y,np.ones(50)*-1))
        prevstate=-1
      else:
        y=np.concatenate((y,np.ones(50)*-1))
        y=np.concatenate((y,np.ones(50)))
        prevstate=1
    elif bit=='1':
      if prevstate==1:
        y=np.concatenate((y,np.ones(50)))
        y=np.concatenate((y,np.ones(50)*-1))
        prevstate=-1
      else:
        y=np.concatenate((y,np.ones(50)*-1))
        y=np.concatenate((y,np.ones(50)))
        prevstate=1


  
  plt.figure(figsize=(15,7))
  plt.xlabel("Sample")
  plt.ylabel("Amplitude")
  plt.yticks([-1,0,1])
  plt.title("Differential Manchester")
  plt.xlim(-.05,len(data))
  plt.plot(x,y)
      
    


data=input("Enter data ")
differentialManchester(data)
# Out:
# Enter data 010011
